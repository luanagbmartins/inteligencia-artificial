# %%
import skfuzzy as fuzz

# %%
import pandas as pd
import numpy as np
import re
df = pd.read_csv('fuzzy_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  id  integralizacao  media_programacao  media_matematica  \
# 0           0   1               0           6.550000               7.3
# 1           1   1               1           5.400000               5.2
# 2           2   1               2           4.956250               4.2
# 3           3   1               3           4.822222               NaN
# 4           4   1               4           7.066667               6.9
#
#    media_NE  media_NC  reprovacoes_programacao  reprovacoes_matematica  \
# 0       NaN  6.700000                      1.0                     0.0
# 1  3.800000  5.500000                      6.0                     1.0
# 2  4.709091  5.283333                     12.0                     1.0
# 3  4.466667  6.028571                     13.0                     NaN
# 4  7.066667  6.900000                      0.0                     0.0
#
#    reprovacoes_NE  reprovacoes_NC  quantidade_trancamentos
# 0             NaN             1.0                        1
# 1             1.0             7.0                        1
# 2             9.0             4.0                        1
# 3            10.0             3.0                        1
# 4             0.0             0.0                        1

# %%
def transform_value(value):
    try:
        return int(str(value).rstrip(','))
    except:
        return str(value).rstrip(',')
    
medidas = df\
.groupby(by=['integralizacao'])\
.agg([np.min, np.mean, np.max])\
.transpose()\
.reset_index()\
.applymap(str)\
.apply(lambda x: x + ',')\
.groupby('level_0')\
.apply(lambda x: x.sum())\
.rename(columns=lambda x: transform_value(x))

medidas['level_0'] = medidas['level_0'].apply(lambda x: x.split(',')[0] )
drop = ['id', 'Unnamed: 0']
medidas = medidas[~medidas['level_0'].isin(drop)]


valores = df\
.applymap(str)\
.apply(lambda x: x + ',')\
.groupby(by=['integralizacao'])\
.agg([np.sum])\
.transpose()\
.reset_index()\
.rename(columns=lambda x: transform_value(x))

valores = valores[~valores['level_0'].isin(drop)]

def gen_dict(table, keep):
    table.index = table['level_0']
    table_dict = table\
    .iloc[:, 2:]\
    .to_dict()
    
    for key in table_dict.keys():
        inner_dict = table_dict[key]
        for key2 in inner_dict.keys():
            inner_dict[key2] = inner_dict[key2].split(',')
            inner_dict[key2] = [ x for x in inner_dict[key2] if re.match("^(?=.)([+-]?([0-9]*)(\.([0-9]+))?)$", x) is not None ]
            inner_dict[key2] = [ round(float(x), 2) for x in inner_dict[key2] ]
            inner_dict[key2] = sorted(list(set(inner_dict[key2])))
            
    return table_dict

# %%
gen_dict(medidas, keep)
# Out:
# {0: {'media_NC': [0.0, 4.1, 10.0],
#   'media_NE': [0.0, 3.42, 10.0],
#   'media_matematica': [0.0, 2.72, 10.0],
#   'media_programacao': [0.0, 4.43, 10.0],
#   'quantidade_trancamentos': [0.0, 0.65, 6.0],
#   'reprovacoes_NC': [0.0, 5.52, 26.0],
#   'reprovacoes_NE': [0.0, 1.95, 11.0],
#   'reprovacoes_matematica': [0.0, 1.68, 7.0],
#   'reprovacoes_programacao': [0.0, 4.18, 29.0]},
#  1: {'media_NC': [1.24, 5.49, 10.0],
#   'media_NE': [0.0, 4.65, 10.0],
#   'media_matematica': [0.0, 3.99, 10.0],
#   'media_programacao': [1.19, 5.99, 10.0],
#   'quantidade_trancamentos': [0.0, 0.5, 4.0],
#   'reprovacoes_NC': [0.0, 3.6, 21.0],
#   'reprovacoes_NE': [0.0, 1.96, 11.0],
#   'reprovacoes_matematica': [0.0, 1.43, 8.0],
#   'reprovacoes_programacao': [0.0, 3.18, 20.0]},
#  2: {'media_NC': [0.0, 6.09, 10.0],
#   'media_NE': [0.1, 5.23, 9.6],
#   'media_matematica': [0.0, 5.12, 10.0],
#   'media_programacao': [1.35, 6.32, 10.0],
#   'quantidade_trancamentos': [0.0, 0.37, 4.0],
#   'reprovacoes_NC': [0.0, 2.14, 17.0],
#   'reprovacoes_NE': [0.0, 2.03, 12.0],
#   'reprovacoes_matematica': [0.0, 0.82, 5.0],
#   'reprovacoes_programacao': [0.0, 2.68, 20.0]},
#  3: {'media_NC': [1.38, 6.2, 10.0],
#   'media_NE': [1.0, 5.88, 9.4],
#   'media_matematica': [0.0, 5.18, 10.0],
#   'media_programacao': [1.94, 6.32, 9.58],
#   'quantidade_trancamentos': [0.0, 0.32, 4.0],
#   'reprovacoes_NC': [0.0, 1.74, 17.0],
#   'reprovacoes_NE': [0.0, 1.81, 12.0],
#   'reprovacoes_matematica': [0.0, 0.77, 6.0],
#   'reprovacoes_programacao': [0.0, 2.85, 18.0]},
#  4: {'media_NC': [1.2, 6.13, 10.0],
#   'media_NE': [0.47, 6.45, 9.4],
#   'media_matematica': [0.0, 4.97, 10.0],
#   'media_programacao': [1.38, 6.34, 9.8],
#   'quantidade_trancamentos': [0.0, 0.25, 4.0],
#   'reprovacoes_NC': [0.0, 1.23, 13.0],
#   'reprovacoes_NE': [0.0, 1.14, 10.0],
#   'reprovacoes_matematica': [0.0, 0.69, 5.0],
#   'reprovacoes_programacao': [0.0, 2.07, 18.0]},
#  5: {'media_NC': [0.82, 6.27, 10.0],
#   'media_NE': [0.25, 6.58, 10.0],
#   'media_matematica': [0.0, 5.14, 10.0],
#   'media_programacao': [2.58, 6.53, 9.85],
#   'quantidade_trancamentos': [0.0, 0.17, 4.0],
#   'reprovacoes_NC': [0.0, 0.97, 6.0],
#   'reprovacoes_NE': [0.0, 0.93, 9.0],
#   'reprovacoes_matematica': [0.0, 0.59, 3.0],
#   'reprovacoes_programacao': [0.0, 1.65, 14.0]},
#  6: {'media_NC': [1.6, 6.64, 10.0],
#   'media_NE': [2.78, 7.08, 9.7],
#   'media_matematica': [0.6, 5.4, 9.5],
#   'media_programacao': [2.74, 6.9, 9.85],
#   'quantidade_trancamentos': [0.0, 0.14, 4.0],
#   'reprovacoes_NC': [0.0, 0.84, 6.0],
#   'reprovacoes_NE': [0.0, 0.78, 6.0],
#   'reprovacoes_matematica': [0.0, 0.6, 4.0],
#   'reprovacoes_programacao': [0.0, 1.37, 10.0]},
#  7: {'media_NC': [3.46, 7.06, 10.0],
#   'media_NE': [2.1, 7.18, 10.0],
#   'media_matematica': [0.7, 6.29, 9.8],
#   'media_programacao': [4.75, 7.1, 9.3],
#   'quantidade_trancamentos': [0.0, 0.15, 4.0],
#   'reprovacoes_NC': [0.0, 0.56, 6.0],
#   'reprovacoes_NE': [0.0, 0.51, 4.0],
#   'reprovacoes_matematica': [0.0, 0.32, 4.0],
#   'reprovacoes_programacao': [0.0, 0.96, 8.0]},
#  8: {'media_NC': [1.5, 7.18, 10.0],
#   'media_NE': [1.03, 7.41, 9.5],
#   'media_matematica': [1.5, 6.25, 8.5],
#   'media_programacao': [1.74, 7.27, 9.4],
#   'quantidade_trancamentos': [0.0, 0.1, 4.0],
#   'reprovacoes_NC': [0.0, 0.32, 4.0],
#   'reprovacoes_NE': [0.0, 0.49, 5.0],
#   'reprovacoes_matematica': [0.0, 0.22, 1.0],
#   'reprovacoes_programacao': [0.0, 0.64, 6.0]},
#  9: {'media_NC': [6.1, 8.02, 10.0],
#   'media_NE': [4.0, 8.03, 10.0],
#   'media_matematica': [6.0, 7.15, 10.0],
#   'media_programacao': [4.0, 8.01, 10.0],
#   'quantidade_trancamentos': [0.0, 0.04, 2.0],
#   'reprovacoes_NC': [0.0, 0.05, 1.0],
#   'reprovacoes_NE': [0.0, 0.15, 2.0],
#   'reprovacoes_matematica': [0.0],
#   'reprovacoes_programacao': [0.0, 0.19, 3.0]},
#  10: {'media_NC': [7.33, 7.96, 8.9],
#   'media_NE': [8.9, 9.2, 9.75],
#   'media_matematica': [8.3, 8.68, 9.15],
#   'media_programacao': [7.5, 8.35, 9.2],
#   'quantidade_trancamentos': [0.0],
#   'reprovacoes_NC': [0.0, 0.2, 1.0],
#   'reprovacoes_NE': [0.0],
#   'reprovacoes_matematica': [0.0],
#   'reprovacoes_programacao': [0.0, 0.2, 1.0]}}

# %%
import seaborn as sns
sns.distplot(pd.DataFrame(gen_dict(valores, keep)[0]['media_programacao']).values.flatten() )
