# %%
import skfuzzy as fuzz
import pandas as pd
import numpy as np
import re
df = pd.read_csv('fuzzy_dataset.csv')

# %%
def transform_value(value):
    try:
        return int(str(value).rstrip(','))
    except:
        return str(value).rstrip(',')
    
medidas = df\
.groupby(by=['integralizacao'])\
.agg([np.min, np.mean, np.max])\
.transpose()\
.reset_index()\
.applymap(str)\
.apply(lambda x: x + ',')\
.groupby('level_0')\
.apply(lambda x: x.sum())\
.rename(columns=lambda x: transform_value(x))

medidas['level_0'] = medidas['level_0'].apply(lambda x: x.split(',')[0] )
drop = ['id', 'Unnamed: 0']
medidas = medidas[~medidas['level_0'].isin(drop)]


valores = df\
.applymap(str)\
.apply(lambda x: x + ',')\
.groupby(by=['integralizacao'])\
.agg([np.sum])\
.transpose()\
.reset_index()\
.rename(columns=lambda x: transform_value(x))

valores = valores[~valores['level_0'].isin(drop)]

def gen_dict(table):
    table.index = table['level_0']
    table_dict = table\
    .iloc[:, 2:]\
    .to_dict()
    
    for key in table_dict.keys():
        inner_dict = table_dict[key]
        for key2 in inner_dict.keys():
            inner_dict[key2] = inner_dict[key2].split(',')
            inner_dict[key2] = [ x for x in inner_dict[key2] if re.match("^(?=.)([+-]?([0-9]*)(\.([0-9]+))?)$", x) is not None ]
            inner_dict[key2] = [ round(float(x), 2) for x in inner_dict[key2] ]
            inner_dict[key2] = sorted(list(set(inner_dict[key2])))
            
    return table_dict

# %%
import seaborn as sns

# %%
def flatten_dict(df):
    tmp = gen_dict(df)
    rows = []
    for key in sorted(tmp.keys()):
        for key2 in sorted(tmp[key].keys()):
            for value in tmp[key][key2]:
                row = {
                    "integralizacao": key,
                    "campo": key2,
                    "valor": value
                }
                rows.append(row)
    return pd.DataFrame(rows)

dataplot = flatten_dict(valores)
dataplot = dataplot[dataplot['campo'].str.contains('media')]
dataplot = dataplot\
.groupby(by=['integralizacao', 'campo'])\
.agg([np.mean])\
.reset_index()
dataplot.columns = dataplot.columns.get_level_values(0)
dataplot['valor'] = dataplot['valor'].apply(lambda x: 1 if x >= 6.0 else 0)
dataplot
# Out:
#     integralizacao              campo  valor
# 0                0           media_NC      0
# 1                0           media_NE      0
# 2                0   media_matematica      0
# 3                0  media_programacao      0
# 4                1           media_NC      0
# 5                1           media_NE      0
# 6                1   media_matematica      0
# 7                1  media_programacao      0
# 8                2           media_NC      1
# 9                2           media_NE      0
# 10               2   media_matematica      0
# 11               2  media_programacao      1
# 12               3           media_NC      1
# 13               3           media_NE      0
# 14               3   media_matematica      0
# 15               3  media_programacao      1
# 16               4           media_NC      0
# 17               4           media_NE      1
# 18               4   media_matematica      0
# 19               4  media_programacao      1
# 20               5           media_NC      0
# 21               5           media_NE      1
# 22               5   media_matematica      0
# 23               5  media_programacao      1
# 24               6           media_NC      1
# 25               6           media_NE      1
# 26               6   media_matematica      0
# 27               6  media_programacao      1
# 28               7           media_NC      1
# 29               7           media_NE      1
# 30               7   media_matematica      1
# 31               7  media_programacao      1
# 32               8           media_NC      1
# 33               8           media_NE      1
# 34               8   media_matematica      1
# 35               8  media_programacao      1
# 36               9           media_NC      1
# 37               9           media_NE      1
# 38               9   media_matematica      1
# 39               9  media_programacao      1
# 40              10           media_NC      1
# 41              10           media_NE      1
# 42              10   media_matematica      1
# 43              10  media_programacao      1

# %%
import pandas as pd  
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

def regressao(df, idx):
    rows = []
    tmp = df[df['integralizacao']==idx].iloc[:, 3:]
    for item in tmp.columns:
        for item2 in tmp.columns:
            if item != item2:
                tmp2 = tmp[[item, item2]].dropna()
                X = tmp2[item].values.reshape(-1, 1)
                y = tmp2[item2].values.reshape(-1, 1)
                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
                regressor = LinearRegression()
                regressor.fit(X_train, y_train)
                y_pred = regressor.predict(X_test)
                row = { 'mse' : metrics.mean_absolute_error(y_test, y_pred),
                       'a' : item,
                       'b' : item2 }
                rows.append(row)
    tmp_df = pd.DataFrame(rows).sort_values(by='mse')
    tmp_df['a'] = tmp_df['a'].combine(tmp_df['b'], lambda x,y: x + ',' + y)
    tmp_df = tmp_df[['mse', 'a']]
    tmp_df = tmp_df[tmp_df['mse'] != 0]
    return tmp_df.head(5)

# %%
result = regressao(df, 0)
result['integralizacao'] = 0
for item in set(df['integralizacao'].values):
    if item != 0:
        tmp = regressao(df, item)
        tmp['integralizacao'] = item
        result = result.append(tmp)

# %%
result['mse'] = result['mse'].round(2)
result
# Out:
#      mse                                                a  integralizacao
# 2   0.48                       media_programacao,media_NC               0
# 24  0.50                       media_NC,media_programacao               0
# 61  0.53            reprovacoes_NC,reprovacoes_matematica               0
# 47  0.70   reprovacoes_matematica,quantidade_trancamentos               0
# 15  0.73         media_matematica,quantidade_trancamentos               0
# 61  0.67            reprovacoes_NC,reprovacoes_matematica               1
# 63  0.69           reprovacoes_NC,quantidade_trancamentos               1
# 31  0.70                 media_NC,quantidade_trancamentos               1
# 24  0.71                       media_NC,media_programacao               1
# 2   0.73                       media_programacao,media_NC               1
# 39  0.50  reprovacoes_programacao,quantidade_trancamentos               2
# 7   0.50        media_programacao,quantidade_trancamentos               2
# 63  0.55           reprovacoes_NC,quantidade_trancamentos               2
# 31  0.55                 media_NC,quantidade_trancamentos               2
# 16  0.58                       media_NE,media_programacao               2
# 15  0.47         media_matematica,quantidade_trancamentos               3
# 12  0.49          media_matematica,reprovacoes_matematica               3
# 28  0.49                  media_NC,reprovacoes_matematica               3
# 61  0.49            reprovacoes_NC,reprovacoes_matematica               3
# 55  0.51           reprovacoes_NE,quantidade_trancamentos               3
# 23  0.34                 media_NE,quantidade_trancamentos               4
# 55  0.35           reprovacoes_NE,quantidade_trancamentos               4
# 7   0.35        media_programacao,quantidade_trancamentos               4
# 39  0.37  reprovacoes_programacao,quantidade_trancamentos               4
# 53  0.39            reprovacoes_NE,reprovacoes_matematica               4
# 47  0.20   reprovacoes_matematica,quantidade_trancamentos               5
# 15  0.20         media_matematica,quantidade_trancamentos               5
# 39  0.23  reprovacoes_programacao,quantidade_trancamentos               5
# 7   0.25        media_programacao,quantidade_trancamentos               5
# 55  0.27           reprovacoes_NE,quantidade_trancamentos               5
# 63  0.17           reprovacoes_NC,quantidade_trancamentos               6
# 31  0.18                 media_NC,quantidade_trancamentos               6
# 23  0.21                 media_NE,quantidade_trancamentos               6
# 55  0.21           reprovacoes_NE,quantidade_trancamentos               6
# 7   0.22        media_programacao,quantidade_trancamentos               6
# 23  0.21                 media_NE,quantidade_trancamentos               7
# 55  0.22           reprovacoes_NE,quantidade_trancamentos               7
# 39  0.25  reprovacoes_programacao,quantidade_trancamentos               7
# 7   0.25        media_programacao,quantidade_trancamentos               7
# 12  0.25          media_matematica,reprovacoes_matematica               7
# 47  0.04   reprovacoes_matematica,quantidade_trancamentos               8
# 63  0.10           reprovacoes_NC,quantidade_trancamentos               8
# 31  0.10                 media_NC,quantidade_trancamentos               8
# 15  0.13         media_matematica,quantidade_trancamentos               8
# 55  0.15           reprovacoes_NE,quantidade_trancamentos               8
# 52  0.02           reprovacoes_NE,reprovacoes_programacao               9
# 37  0.02           reprovacoes_programacao,reprovacoes_NE               9
# 7   0.05        media_programacao,quantidade_trancamentos               9
# 23  0.06                 media_NE,quantidade_trancamentos               9
# 30  0.06                          media_NC,reprovacoes_NC               9
# 60  0.00           reprovacoes_NC,reprovacoes_programacao              10
# 38  0.00           reprovacoes_programacao,reprovacoes_NC              10
# 26  0.00                                media_NC,media_NE              10
# 6   0.05                 media_programacao,reprovacoes_NC              10
# 3   0.05        media_programacao,reprovacoes_programacao              10

# %%
df
# Out:
#       Unnamed: 0   id  integralizacao  media_programacao  media_matematica  \
# 0              0    1               0           6.550000               7.3
# 1              1    1               1           5.400000               5.2
# 2              2    1               2           4.956250               4.2
# 3              3    1               3           4.822222               NaN
# 4              4    1               4           7.066667               6.9
# ...          ...  ...             ...                ...               ...
# 2978        2978  849               0           5.166667               4.9
# 2979        2979  850               2           8.200000               6.3
# 2980        2980  851               0           3.333333               0.2
# 2981        2981  852               0           0.100000               0.0
# 2982        2982  853               0           4.800000               0.4
#
#       media_NE  media_NC  reprovacoes_programacao  reprovacoes_matematica  \
# 0          NaN  6.700000                      1.0                     0.0
# 1     3.800000  5.500000                      6.0                     1.0
# 2     4.709091  5.283333                     12.0                     1.0
# 3     4.466667  6.028571                     13.0                     NaN
# 4     7.066667  6.900000                      0.0                     0.0
# ...        ...       ...                      ...                     ...
# 2978       NaN  5.100000                      2.0                     1.0
# 2979       NaN  7.725000                      0.0                     0.0
# 2980       NaN  2.550000                      2.0                     1.0
# 2981       NaN  0.075000                      3.0                     1.0
# 2982       NaN  3.700000                      2.0                     1.0
#
#       reprovacoes_NE  reprovacoes_NC  quantidade_trancamentos
# 0                NaN             1.0                        1
# 1                1.0             7.0                        1
# 2                9.0             4.0                        1
# 3               10.0             3.0                        1
# 4                0.0             0.0                        1
# ...              ...             ...                      ...
# 2978             NaN             3.0                        0
# 2979             NaN             0.0                        0
# 2980             NaN             3.0                        0
# 2981             NaN             4.0                        0
# 2982             NaN             3.0                        0
#
# [2983 rows x 12 columns]
